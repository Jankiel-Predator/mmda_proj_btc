# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error, mean_squared_log_error

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
from tensorflow.random import set_seed
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

set_seed(455)
np.random.seed(455)

# %%
dataset = pd.read_csv('data/bitcoin/bitcoin_preprocessed.csv', parse_dates=['Date'], index_col = "Date")

# %%
dataset
# Out:
#               Close     Open     High      Low    Volume Change %   Average
# Date
# 2010-07-18      0.1      0.0      0.1      0.1      80.0    0.00%      0.10
# 2010-07-19      0.1      0.1      0.1      0.1     570.0    0.00%      0.10
# 2010-07-20      0.1      0.1      0.1      0.1     260.0    0.00%      0.10
# 2010-07-21      0.1      0.1      0.1      0.1     580.0    0.00%      0.10
# 2010-07-22      0.1      0.1      0.1      0.1    2160.0    0.00%      0.10
# ...             ...      ...      ...      ...       ...      ...       ...
# 2024-12-28  95284.5  94274.9  95684.3  94124.7   32970.0    1.07%  94904.50
# 2024-12-29  93716.3  95282.6  95315.4  93026.7   47710.0   -1.65%  94171.05
# 2024-12-30  92779.8  93718.7  94936.4  91522.3  112430.0   -1.00%  93229.35
# 2024-12-31  93557.2  92777.2  96163.4  92036.2   74850.0    0.84%  94099.80
# 2025-01-01  94560.2  93557.3  95100.0  92939.3   43340.0    1.07%  94019.65
#
# [5282 rows x 7 columns]

# %%
def evaluate_model(test, predicted):
    rmse = np.sqrt(mean_squared_error(test, predicted))
    mae = mean_absolute_error(test, predicted)
    r2 = r2_score(test, predicted)
    msle = mean_squared_log_error(test, predicted)
    mape = np.mean(np.abs((test - predicted) / test)) * 100

    print(f"The root mean squared error (RMSE) is {rmse:.2f}")
    print(f"The Mean Absolute Error (MAE) is {mae:.2f}")
    print(f"The R-squared (R²) score is {r2:.4f}\n")
    print(f"The Mean Squared Logarithmic Error (MSLE) is {msle:.6f}")
    print(f"The Mean Absolute Percentage Error (MAPE) is {mape:.2f}%.")

# %%
def plot_predictions(test, predicted):
    plt.figure(figsize=(16, 9))
    plt.plot(test, color="gray", label="Real")
    plt.plot(predicted, color="red", label="Predicted")
    plt.title("Bitcoin Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("Bitcoin Price ($)")
    plt.legend()
    plt.show()

# %%
# train-test
tstart = "2010-07-18"
tend = "2024-01-10"

# %%
def train_test_plot(dataset, tstart, tend):
    tend_next = pd.to_datetime(tend) + pd.Timedelta(days=1)

    dataset.loc[tstart:tend, "Close"].plot(figsize=(16, 5), legend=True)
    dataset.loc[tend_next:, "Close"].plot(figsize=(16, 5), legend=True)

    plt.legend([f"Train (2010-07-18 to {tend_next.date()})", f"Test ({tend_next.date() + pd.Timedelta(days=1)} up to 2025-01-01)"])
    plt.title("Bitcoin Close Price")
    plt.show()

train_test_plot(dataset, tstart, tend)

# %%
def train_test_split(dataset, tstart, tend):
    tend_next = pd.to_datetime(tend) + pd.Timedelta(days=1)

    train = dataset.loc[tstart:tend, "Close"].values
    test = dataset.loc[tend_next:, "Close"].values
    return train, test

training_set, test_set = train_test_split(dataset, tstart, tend)

# %%
sc = MinMaxScaler(feature_range=(0, 1))
training_set = training_set.reshape(-1, 1)
training_set_scaled = sc.fit_transform(training_set)

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

n_steps = 60
features = 1
# split into samples
X_train, y_train = split_sequence(training_set_scaled, n_steps)

# %%
# Reshaping X_train for model
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],features)

# %%
# The LSTM architecture
model_lstm = Sequential()
model_lstm.add(Bidirectional(LSTM(units=125, activation="tanh", input_shape=(n_steps, features))))
model_lstm.add(Dense(units=1))
# Compiling the model
model_lstm.compile(optimizer="RMSprop", loss="mse")

model_lstm.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# 10 min
model_lstm.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 117ms/step - loss: 0.0086
# Epoch 2/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - loss: 6.9692e-04
# Epoch 3/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - loss: 5.1356e-04
# Epoch 4/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 123ms/step - loss: 4.6489e-04
# Epoch 5/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 21s 127ms/step - loss: 3.8490e-04
# Epoch 6/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - loss: 3.4002e-04
# Epoch 7/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 21s 120ms/step - loss: 3.0297e-04
# Epoch 8/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - loss: 2.7604e-04
# Epoch 9/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - loss: 2.6240e-04
# Epoch 10/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 23s 131ms/step - loss: 2.5072e-04
# Epoch 11/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - loss: 2.3558e-04
# Epoch 12/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - loss: 2.1925e-04
# Epoch 13/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 121ms/step - loss: 2.1022e-04
# Epoch 14/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - loss: 2.0294e-04
# Epoch 15/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 127ms/step - loss: 1.9657e-04
# Epoch 16/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - loss: 1.9053e-04
# Epoch 17/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 21s 121ms/step - loss: 1.8503e-04
# Epoch 18/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - loss: 1.8011e-04
# Epoch 19/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - loss: 1.7571e-04
# Epoch 20/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 127ms/step - loss: 1.7180e-04
# Epoch 21/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - loss: 1.6833e-04
# Epoch 22/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 126ms/step - loss: 1.6524e-04
# Epoch 23/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 116ms/step - loss: 1.6250e-04
# Epoch 24/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 124ms/step - loss: 1.6034e-04
# Epoch 25/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 114ms/step - loss: 1.5846e-04
# Epoch 26/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - loss: 1.5615e-04
# Epoch 27/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 125ms/step - loss: 1.5362e-04
# Epoch 28/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - loss: 1.5114e-04
# Epoch 29/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 23s 130ms/step - loss: 1.4884e-04
# Epoch 30/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - loss: 1.4675e-04
# Epoch 31/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 125ms/step - loss: 1.4484e-04
# Epoch 32/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - loss: 1.4308e-04
# Epoch 33/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 125ms/step - loss: 1.4145e-04
# Epoch 34/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - loss: 1.3992e-04
# Epoch 35/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 117ms/step - loss: 1.3848e-04
# Epoch 36/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.3713e-04
# Epoch 37/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - loss: 1.3585e-04
# Epoch 38/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 127ms/step - loss: 1.3464e-04
# Epoch 39/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - loss: 1.3349e-04
# Epoch 40/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 20s 118ms/step - loss: 1.3239e-04
# Epoch 41/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 21s 118ms/step - loss: 1.3135e-04
# Epoch 42/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - loss: 1.3035e-04
# Epoch 43/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - loss: 1.2940e-04
# Epoch 44/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 115ms/step - loss: 1.2850e-04
# Epoch 45/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 128ms/step - loss: 1.2763e-04
# Epoch 46/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - loss: 1.2679e-04
# Epoch 47/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.2600e-04
# Epoch 48/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - loss: 1.2523e-04
# Epoch 49/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 21s 124ms/step - loss: 1.2450e-04
# Epoch 50/50
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 19s 121ms/step - loss: 1.2379e-04

# %%
def plot_predictions(test, predicted):
    plt.figure(figsize=(16, 9))
    plt.plot(test, color="gray", label="Real")
    plt.plot(predicted, color="red", label="Predicted")
    plt.title("Bitcoin Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("Bitcoin Price ($)")
    plt.legend()
    plt.show()

# %%
model_gru = Sequential()
model_gru.add(GRU(units=125, activation="tanh", input_shape=(n_steps, features)))
model_gru.add(Dense(units=1))
# Compiling the RNN
model_gru.compile(optimizer="RMSprop", loss="mse")

model_gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 125)               48000
#
#  dense_2 (Dense)             (None, 1)                 126
#
# =================================================================
# Total params: 48,126
# Trainable params: 48,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# %%
# 10 min
model_gru.fit(X_train, y_train, epochs=100, batch_size=64, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 77/77 [==============================] - ETA: 0s - loss: 0.0029WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 42ms/step - loss: 0.0029 - lr: 0.0010
# Epoch 2/100
# 76/77 [============================>.] - ETA: 0s - loss: 4.2978e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 47ms/step - loss: 4.2989e-04 - lr: 0.0010
# Epoch 3/100
# 76/77 [============================>.] - ETA: 0s - loss: 4.1048e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 48ms/step - loss: 4.1095e-04 - lr: 0.0010
# Epoch 4/100
# 76/77 [============================>.] - ETA: 0s - loss: 4.5285e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 46ms/step - loss: 4.5284e-04 - lr: 0.0010
# Epoch 5/100
# 76/77 [============================>.] - ETA: 0s - loss: 3.5051e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 48ms/step - loss: 3.5079e-04 - lr: 0.0010
# Epoch 6/100
# 76/77 [============================>.] - ETA: 0s - loss: 3.1165e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 48ms/step - loss: 3.1159e-04 - lr: 0.0010
# Epoch 7/100
# 76/77 [============================>.] - ETA: 0s - loss: 3.0044e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 48ms/step - loss: 3.0040e-04 - lr: 0.0010
# Epoch 8/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.6484e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 49ms/step - loss: 2.6481e-04 - lr: 0.0010
# Epoch 9/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.5518e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 4s 54ms/step - loss: 2.5513e-04 - lr: 0.0010
# Epoch 10/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.4672e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 70ms/step - loss: 2.4670e-04 - lr: 0.0010
# Epoch 11/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.4239e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 63ms/step - loss: 2.4234e-04 - lr: 0.0010
# Epoch 12/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.3632e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 63ms/step - loss: 2.3627e-04 - lr: 0.0010
# Epoch 13/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.4100e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 62ms/step - loss: 2.4096e-04 - lr: 0.0010
# Epoch 14/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.1566e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 62ms/step - loss: 2.1562e-04 - lr: 0.0010
# Epoch 15/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.2202e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 62ms/step - loss: 2.2200e-04 - lr: 0.0010
# Epoch 16/100
# 76/77 [============================>.] - ETA: 0s - loss: 2.0814e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s
100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2610e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 75ms/step - loss: 1.2608e-04 - lr: 0.0010
# Epoch 89/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2949e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 7s 85ms/step - loss: 1.2947e-04 - lr: 0.0010
# Epoch 90/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2059e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 75ms/step - loss: 1.2056e-04 - lr: 0.0010
# Epoch 91/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2896e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 75ms/step - loss: 1.2893e-04 - lr: 0.0010
# Epoch 92/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2349e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 78ms/step - loss: 1.2398e-04 - lr: 0.0010
# Epoch 93/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.4464e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 75ms/step - loss: 1.4461e-04 - lr: 0.0010
# Epoch 94/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2101e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 74ms/step - loss: 1.2099e-04 - lr: 0.0010
# Epoch 95/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2268e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 76ms/step - loss: 1.2266e-04 - lr: 0.0010
# Epoch 96/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2542e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 80ms/step - loss: 1.2540e-04 - lr: 0.0010
# Epoch 97/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2065e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 75ms/step - loss: 1.2062e-04 - lr: 0.0010
# Epoch 98/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.3307e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 6s 81ms/step - loss: 1.3305e-04 - lr: 0.0010
# Epoch 99/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.3135e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 71ms/step - loss: 1.3132e-04 - lr: 0.0010
# Epoch 100/100
# 76/77 [============================>.] - ETA: 0s - loss: 1.2839e-04WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `mse` which is not available. Available metrics are: loss,lr
# 77/77 [==============================] - 5s 71ms/step - loss: 1.2838e-04 - lr: 0.0010

# %%
dataset_total = dataset.loc[:, "Close"]
inputs = dataset_total[len(dataset_total) - len(test_set) - n_steps :].values
inputs = inputs.reshape(-1, 1)
#scaling
inputs = sc.transform(inputs)

# Split into samples
X_test, y_test = split_sequence(inputs, n_steps)
# reshape
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], features)
#prediction
predicted_stock_price = model_gru.predict(X_test)
#inverse transform the values
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 12/12 [==============================] - 0s 7ms/step

# %%
GRU_predicted_stock_price = model_gru.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
plot_predictions(test_set, GRU_predicted_stock_price)
# Out:
# 12/12 [==============================] - 0s 11ms/step

# %%
evaluate_model(test_set, predicted_stock_price)
# Out:
# The root mean squared error (RMSE) is 1903.58
# The Mean Absolute Error (MAE) is 1366.47
# The R-squared (R²) score is 0.9827
#
# The Mean Squared Logarithmic Error (MSLE) is 0.000796
# The Mean Absolute Percentage Error (MAPE) is 23.06%.

# %% [markdown]
# ### Short Comparison
#
# We can compare these two charts and conclude that the **GRU** model is more accurate in predicting latest (higher) prices and ramps up the lower prices at the earlier periods (especially where Time between 200 and 600). The RMSE here is still less, probably because the higher prices have smaller residuals, overshadowing poorer performance earlier (in Time).
#
# On the other hand, **LSTM** is more precise in predicting earlier price movements (compare Time between 200 and 600), whereas it is less robust in identifying the most recent trends.

# %%
# Improved a bit with GRU
return_rmse(test_set, GRU_predicted_stock_price)
# Out:
# The root mean squared error is 2047.40.

# %% [markdown]
# To improve models & RMSE:
# - increase `batch_size`
# - increase or decrease `n_steps` in **split_sequence**
# - train more epochs
# - improve model structure (especially GRU)
# - reducing dataset (e.g. start from 2017)
# - separate normalization over different time windows
# - extend `train_set` (e.g. to 0.85)
# - try various activation functions
